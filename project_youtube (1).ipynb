# %%
# !pip install google-api-python-client
# !pip install mysql-connector-python
# !pip install pymongo
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (2.84.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2024.2.2)
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.4.0-cp310-cp310-manylinux_2_17_x86_64.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 5.8 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-8.4.0
# Collecting pymongo
#   Downloading pymongo-4.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (670 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.0/670.0 kB 9.2 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 35.9 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.7.2

# %%
import googleapiclient.discovery
api_key='AIzaSyA_V9FqIHH_D_ZtOU-YKnG-NEbPVcWiWRI'
api_service_name = "youtube"
api_version ="v3"

# %%
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey=api_key)

# %%
from pprint import pprint

# %%
def get_channel_details(c_id):
  request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=c_id
    )
  response = request.execute()

  data = {"channel_name" : response['items'][0]['snippet']['title'],
          "published_at" : response['items'][0]['snippet']['publishedAt'],
          "p_id" : response['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
          "sub_count" : response['items'][0]['statistics']['subscriberCount'],
          "video_count" : response['items'][0]['statistics']['videoCount'],
          "view_count" : response['items'][0]['statistics']['viewCount']}
  return data

# %%
get_channel_details('UCueYcgdqos0_PzNOq81zAFg')
# Out:
# {'channel_name': 'Parithabangal',
#  'published_at': '2018-02-08T17:44:41Z',
#  'p_id': 'UUueYcgdqos0_PzNOq81zAFg',
#  'sub_count': '5380000',
#  'video_count': '778',
#  'view_count': '1302102826'}

# %%
channel_ids = ["UCJcCB-QYPIBcbKcBQOTwhiA", "UCueYcgdqos0_PzNOq81zAFg", "UCn4rEMqKtwBQ6-oEwbd4PcA"]
channel_details = []
for c_id in channel_ids:
  c_detail = get_channel_details(c_id)
  c_detail['channel_id'] = c_id
  channel_details.append(c_detail)
# Out:
# [{'channel_name': 'Vj Siddhu Vlogs', 'published_at': '2023-06-14T07:41:42.139364Z', 'p_id': 'UUJcCB-QYPIBcbKcBQOTwhiA', 'sub_count': '2490000', 'video_count': '184', 'view_count': '384891438', 'channel_id': 'UCJcCB-QYPIBcbKcBQOTwhiA'}, {'channel_name': 'Parithabangal', 'published_at': '2018-02-08T17:44:41Z', 'p_id': 'UUueYcgdqos0_PzNOq81zAFg', 'sub_count': '5440000', 'video_count': '823', 'view_count': '1348775665', 'channel_id': 'UCueYcgdqos0_PzNOq81zAFg'}, {'channel_name': 'Sony Music South', 'published_at': '2014-08-06T15:11:11Z', 'p_id': 'UUn4rEMqKtwBQ6-oEwbd4PcA', 'sub_count': '17100000', 'video_count': '3460', 'view_count': '12328051498', 'channel_id': 'UCn4rEMqKtwBQ6-oEwbd4PcA'}]

# %%
def get_comment_details(video_id):
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=50
    )
    response = request.execute()

    comments = []
    for item in response['items']:
       # print(item)
        comment_data = {
            "comment_id": item['id'],
            "video_id": item['snippet']['videoId'],
            "comment_text": item['snippet']['topLevelComment']['snippet']['textOriginal'],
            "comment_author": item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
            "comment_published_At": item['snippet']['topLevelComment']['snippet']['publishedAt']
        }
        comments.append(comment_data)
    return comments

# %%
def extract_iso_time(dur):
    dur = dur[2:]
    h = dur.find('H')
    m = dur.find('M')
    s = dur.find('Y')
    hours, minutes, seconds = 0, 0, 0
    if h >= 0:
        hours = dur[:h]
    if m >= 0:
        minutes = dur[h+1:m]
    if s >= 0:
      seconds = dur[m+1:s]

    return (int(hours) * 3600) +  (int(minutes) * 60) + int(seconds)


extract_iso_time('PT1M')
# Out:
# 60

# %%
def get_video_details(v_id):
  request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=v_id
    )
  response = request.execute()
  # pprint(response['items'][0])

  video_data = {"video_name" : response['items'][0]['snippet']['title'],
                "channel_id": response['items'][0]['snippet']['channelId'],
                "video_id" : response['items'][0]['id'],
                "public_At" : response['items'][0]['snippet']['publishedAt'],
                "comment_count" : response['items'][0]['statistics']['commentCount'],
                "favourite_count" : response['items'][0]['statistics']['favoriteCount'],
                "like_count" : response['items'][0]['statistics']['likeCount'],
                "vid_view_count" : response['items'][0]['statistics']['viewCount'],
                "vid_duration": extract_iso_time(response['items'][0]['contentDetails']['duration']),
                "video_description" : response['items'][0]['snippet']['localized']['description']}
  return video_data

# %%
get_video_details('WcOm6gUN4DA')
# Out:
# {'video_name': 'எங்க தான்டா Ticket கிடைக்கும்!? #shorts | Parithabangal',
#  'channel_id': 'UCueYcgdqos0_PzNOq81zAFg',
#  'video_id': 'WcOm6gUN4DA',
#  'public_At': '2024-04-05T11:34:34Z',
#  'comment_count': '29',
#  'favourite_count': '0',
#  'like_count': '9474',
#  'vid_view_count': '115459',
#  'vid_duration': 60,
#  'video_description': '#parithabangal #shorts #paavangal #iplticketpaavangal #iplpaavangal #ipl \n\n________________________________\n\nStarring\n\nGO-SU\nhttps://www.instagram.com/gopi_aravindh\nhttps://www.instagram.com/duniya_sudhakar\nDravid Selvam: https://www.instagram.com/dravidselvam_6\n\n________________________________\n\nFollow our new channel : \nParithabangal Podcast  - https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n\nFollow Us On Social Media\n\nPARITHABANGAL \n\nFacebook    -  https://www.facebook.com/ParithabangalProductions/ \nInstagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\nTwitter     -  https://twitter.com/Parithabangal_\nYoutube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n___________________________________\n\nIn Association with Divo :\nWebsite   - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook  - http://www.facebook.com/divomovies\nTwitter   - https://twitter.com/divomovies\n_____________________________________'}

# %%
def get_videos_for_channel(channel, count=50):

    request = youtube.playlistItems().list(
        part='contentDetails',
        maxResults=count,
        playlistId=channel['p_id']
      )
    response = request.execute()
    video_ids=[]
    videos=[]
    for item in response['items'][1:]:
        # print(item)
        video_id = item['contentDetails']['videoId']
        video_ids.append(video_id)
        video_details = get_video_details(video_id)
        video_details['comments'] = get_comment_details(video_id)
        videos.append(video_details)
        video_details.update(channel)
    return videos

videos = []
for channel in channel_details:
  # print(channel['p_id'])
  videos.extend(get_videos_for_channel(channel))

# len(videos)
# Out:
# {'kind': 'youtube#playlistItem', 'etag': 'M-X4a0Z-EBtKtyDw5xpLNeyquGk', 'id': 'VVVKY0NCLVFZUElCY2JLY0JRT1R3aGlBLkhkbURZVmtvN25J', 'contentDetails': {'videoId': 'HdmDYVko7nI', 'videoPublishedAt': '2024-05-19T04:30:08Z'}}
# {'kind': 'youtube#playlistItem', 'etag':
z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'lIYF1YPlbq2pMFLgvKptreYwKgE', 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLl9IeHV0cGpqdmFN', 'contentDetails': {'videoId': '_HxutpjjvaM', 'videoPublishedAt': '2024-04-24T07:14:07Z'}}
# {'kind': 'youtube#playlistItem', 'etag': '3L0GuxR57YOuDkfJlk9BdeP_BHI', 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLlBLQjA3dU45ck8w', 'contentDetails': {'videoId': 'PKB07uN9rO0', 'videoPublishedAt': '2024-04-23T12:30:16Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'obsOj4n6kjFOP15bE5lbdjmYYJI', 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLkdZNlJGRC11ZWpV', 'contentDetails': {'videoId': 'GY6RFD-uejU', 'videoPublishedAt': '2024-04-23T10:30:16Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'UJol-r0vNgdB6IKb1UlfbuhkZyw', 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLks1TDJlT1cyc3pZ', 'contentDetails': {'videoId': 'K5L2eOW2szY', 'videoPublishedAt': '2024-04-23T07:32:06Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'qbZ69FBqvtF-GuJq3BiVUpqyh6E', 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLnZhSXgxbEpxYVVv', 'contentDetails': {'videoId': 'vaIx1lJqaUo', 'videoPublishedAt': '2024-04-22T18:03:19Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'NNEDbDWb414kXl-R29OfuhkPMq0', 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLlVJY1dUZVRER2pR', 'contentDetails': {'videoId': 'UIcWTeTDGjQ', 'videoPublishedAt': '2024-04-22T13:25:10Z'}}

# %%
get_video_details('hAh-SE-_Hns')
# Out:
# {'video_name': 'Mazhavillu Malayalam Songs Jukebox | Mohan Sithara | Kunchako Boban, Vineeth, Preeti Jhangiani',
#  'channel_id': 'UCn4rEMqKtwBQ6-oEwbd4PcA',
#  'video_id': 'hAh-SE-_Hns',
#  'public_At': '2024-03-26T18:30:27Z',
#  'comment_count': '0',
#  'favourite_count': '0',
#  'like_count': '7',
#  'vid_view_count': '743',
#  'vid_duration': 3060,
#  'video_description': 'Music Label - Sony Music Entertainment India Pvt. Ltd.\n\n© 2023 Sony Music Entertainment India Pvt. Ltd.\n\nSubscribe Now: http://bit.ly/SonyMusicSouthVevo\nSubscribe Now: http://bit.ly/SonyMusicSouthYT\nFollow us: https://www.instagram.com/sonymusic_south/\nFollow us: Twitter: https://twitter.com/SonyMusicSouth\nLike us: Facebook: https://www.facebook.com/SonyMusicSouth\nJoin our WhatsApp broadcast channel https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\nJoin Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'}

# %%
from pymongo import MongoClient
connection = MongoClient("mongodb+srv://yuvarajs:guvi2024@cluster0.bk244m9.mongodb.net/")
db = connection.youtube
collection = db.video_details
#collection.insert_many(videos)

# %%
result = collection.find({})
result = list(result)

channel_table = []
comments_table = []
videos_table = []

for channel in channel_details:
  keys = ['channel_name', 'channel_id', 'published_at', 'p_id', 'sub_count', 'video_count','view_count']
  channel_table.append([channel[key] for key in keys])

for video in videos:
  keys = ['video_id', 'channel_id', 'video_name', 'public_At', 'comment_count', 'favourite_count', 'like_count' , 'vid_view_count', 'vid_duration','video_description']
  videos_table.append([video[key] for key in keys])
  for comment in video['comments']:
    comment_keys = ['comment_id', 'video_id', 'comment_text', 'comment_author', 'comment_published_At']
    comments_table.append([comment[key] for key in comment_keys])

# %%
pprint(channel_details)
# Out:
# [{'channel_id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'channel_name': 'Vj Siddhu Vlogs',
#   'p_id': 'UUJcCB-QYPIBcbKcBQOTwhiA',
#   'published_at': '2023-06-14T07:41:42.139364Z',
#   'sub_count': '2490000',
#   'video_count': '184',
#   'view_count': '384891438'},
#  {'channel_id': 'UCueYcgdqos0_PzNOq81zAFg',
#   'channel_name': 'Parithabangal',
#   'p_id': 'UUueYcgdqos0_PzNOq81zAFg',
#   'published_at': '2018-02-08T17:44:41Z',
#   'sub_count': '5440000',
#   'video_count': '823',
#   'view_count': '1348775665'},
#  {'channel_id': 'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'channel_name': 'Sony Music South',
#   'p_id': 'UUn4rEMqKtwBQ6-oEwbd4PcA',
#   'published_at': '2014-08-06T15:11:11Z',
#   'sub_count': '17100000',
#   'video_count': '3460',
#   'view_count': '12328051498'}]

# %%
import pandas as pd
import sqlite3
con = sqlite3.connect("youtube_Details.db")
cur = con.cursor()

# %%
def create_video_table(curr, drop=False):
  if drop:
    curr.execute("drop table if exists videos")
  curr.execute("CREATE TABLE videos(video_id, channel_id, video_name, public_At, comment_count INTEGER, favourite_count INTEGER, like_count INTEGER, vid_view_count INTEGER,vid_duration INTEGER,video_description) ")

def create_comments_table(curr, drop=False):
    if drop:
      curr.execute("drop table if exists comments")
    curr.execute("CREATE TABLE comments(comment_id, video_id, comment_text, comment_author, comment_published_At) ")

def create_channels_table(curr, drop=False):
    if drop:
      curr.execute("drop table if exists channels")
    curr.execute("CREATE TABLE channels(channel_name, channel_id, published_at, p_id, sub_count INTEGER, video_count INTEGER,view_count INTEGER) ")

# create_video_table(cur, drop=False)
# create_comments_table(cur, drop=False)
# create_channels_table(cur, drop=False)

# %%
def insert_videos(curr, videos):
  curr.executemany ("""INSERT INTO videos(video_id, channel_id, video_name, public_At, comment_count, favourite_count, like_count, vid_view_count, vid_duration, video_description)
                                 VALUES (?,?,?,?,?,?,?,?,?,?)""" , videos)

def insert_comments(curr, comments):
  curr.executemany("""INSERT INTO comments(comment_id, video_id, comment_text, comment_author, comment_published_At) VALUES (?,?,?,?,?)""", comments)

def insert_channels(curr, channels):
  curr.executemany("""INSERT INTO channels(channel_name, channel_id, published_at, p_id, sub_count, video_count,view_count) VALUES (?, ?, ?, ?, ?, ?, ?)""", channels)

# %%
# from pickle import TRUE
insert_videos(cur, videos_table)
insert_comments(cur, comments_table)
insert_channels(cur, channel_table)

# %%
pprint(videos_table)
# Out:
# Streaming output truncated to the last 5000 lines.
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['tIMDNFKKq74',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Sorry இனியாழ்\U0001f979 | Dubai Series EP 3 | Vj Siddhu Vlogs',
#   '2024-03-27T09:45:08Z',
#   '2288',
#   '0',
#   '177134',
#   '2389303',
#   900,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #dubaiseries #dubaivlog \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['3Hi7I81gtXs',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Direction விட Acting ஜாலியா இருக்கு 😜 | Vj Siddhu Vlogs',
#   '2024-03-25T09:30:08Z',
#   '2651',
#   '0',
#   '190259',
#   '2459728',
#   1260,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #lokeshkanagaraj #shruthihaasan #inimel \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['Ked0saxns6Q',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'தலைவர் படத்துல நடிக்க போறோம் 😍🔥 | Lokesh Kanagaraj | VJ Siddhu Vlogs',
#   '2024-03-24T04:30:08Z',
#   '2616',
#   '0',
#   '197491',
#   '2485505',
#   1380,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #lokeshkanagaraj #shruthihaasan \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['baxuANxNlfI',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Sabbu - வின் உண்மை காதல் ❤️🥺 | Dubai Series Ep 02 | Vj Siddhu Vlogs',
#   '2024-03-22T09:30:08Z',
#   '3468',
#   '0',
#   '163423',
#   '2303434',
#   1020,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #dubaiseries #dubaivlog \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['ZoI2wfj_OX0',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Welcome to Ini vlogs | Dubai Series Ep 01 | Vj Siddhu Vlogs',
#   '2024-03-20T12:30:08Z',
#   '3696',
#   '0',
#   '212808',
#   '3115798',
#   1680,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #DubaiVlog #Dubaiseries \n'
#   '\n'
#   'GT Holidays:\n'
#   'Contact GT holidays for Tour Packages all across the globe\n'
#   'For more details : https://www.gtholidays.in/\n'
#   'Call : 9940882200\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['PKUCLg6xOeY',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'பரிசல் Boating🛶, Boys Are Waiting🤩 | Vj Siddhu Vlogs',
#   '2024-03-18T14:45:08Z',
#   '3267',
#   '0',
#   '173996',
#   '2459756',
#   1320,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   "Experience the breathtaking beauty of our Hogenakkal's boating adventure in "
#   'this immersive video. Join us as we explore the serene Parisel boating '
#   'experience\n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #hogenakkal #hogenakkalwaterfalls '
#   '#hogenakkalfalls \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['u9tDHRYUJok',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Soori வேலைய காட்டிட்டான் 🤦🏻\u200d♂️ | Vj Siddhu Vlogs',
#   '2024-03-17T04:30:13Z',
#   '6647',
#   '0',
#   '199571',
#   '2788518',
#   1620,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #salemtrip \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['qPyhETU3VjA',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'கல்யாணத்துக்கு போன மாறித்தான்👀🥴 | Vj Siddhu Vlogs',
#   '2024-03-15T10:15:08Z',
#   '2038',
#   '0',
#   '151439',
#   '2206281',
#   960,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #salemvlog #salem #dharmapuri \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['sCq4qwwVmx0',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'இப்படி ஒரு புள்ளை நமக்கு தேவையா😂💥 | Vj Siddhu Vlogs',
#   '2024-03-13T09:30:08Z',
#   '2131',
#   '0',
#   '156467',
#   '2343837',
#   1500,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #shoppingvlog \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['301HsAA3z1c',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'கல்யாணத்துக்கு அவசியம் போணுமா😱🤔 | Epi 02 | Vj Siddhu Vlogs',
#   '2024-03-11T09:45:08Z',
#   '1910',
#   '0',
#   '151114',
#   '2362161',
#   960,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #salemtrip #travelvlog \n'
#   '\n'
#   'For FRANCHISE Enquiry, \n'
#   '\n'
#   'Phone Number:\n'
#   '\n'
#   '+91 9489662489\n'
#   '+91 9673245678\n'
#   '\n'
#   'TEA TIME is one of the largest Tea brand of India, having chain of 4000+  '
#   'Outlets across 20 States in INDIA and 1100+ Outlets in TAMILNADU.\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['szatZqT3B94',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Friendu கல்யாணத்துக்கு கிளம்பிட்டோம் 🥳😍 | Vj Siddhu Vlogs',
#   '2024-03-10T04:30:08Z',
#   '2146',
#   '0',
#   '166277',
#   '2745901',
#   1140,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #vjsiddhutrip \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['ObJvAJbe8HY',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   '8 மணிநேரம் road-ல இருக்க முடியுமா? 🤷🏻\u200d♂️ | Srilanka Epi - 13 | Vj '
#   'Siddhu Vlogs',
#   '2024-03-08T12:30:08Z',
#   '1938',
#   '0',
#   '145317',
#   '1942056',
#   1020,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com\n'
#   ' \n'
#   '#vjsiddhuvlogs #funvlogs #srilankaseries #srilanka #flightcancelled \n'
#   '\n'
#   'GT Holidays:\n'
#   'Contact GT holidays for Tour Packages all across the globe\n'
#   'For more details : https://www.gtholidays.in/\n'
#   'Call : 9940882200\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['c1HX_EbZYAo',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'தானா சேர்ந்த கூட்டம் 🤩🔥 | Sri Lanka Ep-12 | Vj Siddhu Vlogs',
#   '2024-03-06T10:45:08Z',
#   '1142',
#   '0',
#   '106315',
#   '1224312',
#   900,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #srilankaseries #shakthifm \n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['o-Cc6jq916M',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'நல்லூர் முருகன் கோவிலுக்கு போறோம்🙏🏻😍 | Sri Lanka Ep-11 | Vj Siddhu Vlogs',
#   '2024-03-04T12:45:09Z',
#   '2159',
#   '0',
#   '133444',
#   '1739258',
#   1620,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #srilankaseries #jaffna #jaffnapubliclibrary \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['RMwC_4oxKT0',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Twitter -ல இதான் பாக்குறியா 😨? | Sri Lanka EP-10 | Vj Siddhu Vlogs',
#   '2024-03-03T04:30:11Z',
#   '2161',
#   '0',
#   '152697',
#   '2171299',
#   1260,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '#vjsiddhuvlogs #funvlogs #srilankaseries \n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['cu_kqf70vEg',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'நான் கேட்டது ஆனா அவர் குடுத்தது🤭😂 | Vj Siddhu Vlogs',
#   '2024-03-01T11:30:09Z',
#   '2909',
#   '0',
#   '183918',
#   '2484054',
#   1860,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #joshuvamovie #gvm #mottamaadyparty\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['6ZX8gywf6sQ',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Friendship தான் சொத்து நமக்கு😍🥰 | Sri Lanka EP-9 | Vj Siddhu Vlogs',
#   '2024-02-28T09:30:12Z',
#   '2237',
#   '0',
#   '149882',
#   '2093794',
#   1200,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #srilankaseries #srilanka #templevisit \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['oVHwoZaMD-s',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'மாமாவுக்கு கோவம் வந்துருச்சு 😠 | Sri Lanka EP-8 | Vj Siddhu Vlog',
#   '2024-02-26T13:15:12Z',
#   '2309',
#   '0',
#   '164726',
#   '2686331',
#   1380,
#   'GT Holidays:\n'
#   'Contact GT holidays for Tour Packages all across the globe\n'
#   'For more details : https://www.gtholidays.in/\n'
#   'Call : 9940882200\n'
#   '\n'
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '\n'
#   '#vjsiddhuvlogs #funvlogs #srilankaseries #cooking \n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['fT9yAjUHzwQ',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'புது Game-uh, Siddhu செம்ம Form-uh 😎🤣 | Sri Lanka EP-7 | Vj Siddhu Vlogs',
#   '2024-02-25T04:30:11Z',
#   '1357',
#   '0',
#   '144689',
#   '2020153',
#   960,
#   'For Business inquiries please contact us :7200571056\n'
#   'Gmail : vjsidduvlogsadv@gmail.com \n'
#   '#vjsiddhuvlogs #funvlogs\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'Follow My Social Media Pages \n'
#   '\n'
#   'Facebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n'
#   'Instagram :- '
#   'https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\n'
#   'Page Instagram :- '
#   'https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n'
#   '\n'
#   '___________________________________\n'
#   '\n'
#   'In Association with DIVO - Digital Partner\n'
#   'Website - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook - http://www.facebook.com/divomovies\n'
#   'Twitter - https://twitter.com/divomovies'],
#  ['gKjk4vprD14',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'இவங்கள சமாளிக்க முடியலடா😣😥 #shorts | Parithabangal',
#   '2024-05-19T11:30:15Z',
#   '54',
#   '0',
#   '8112',
#   '101481',
#   60,
#   '#parithabangal #shorts #paavangal #summervacationpaavangal #summervaction '
#   '#vacationpaavangal\n'
#   '\n'
#   '_______________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['PL1a6gtckc8',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'Summer Vacation Paavangal | Parithabangal',
#   '2024-05-19T05:30:09Z',
#   '1405',
#   '0',
#   '55098',
#   '984125',
#   840,
#   '#parithabangal #paavangal #summervacationpaavangal #summervaction '
#   '#vacationpaavangal\n'
#   '\n'
#   '_______________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['tnKdmIWrW_4',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'தாய்கிழவி Gap-ல திட்டிட்டு போகுது பாரு😂😒 | Parithabangal #shorts',
#   '2024-05-18T12:06:38Z',
#   '159',
#   '0',
#   '23375',
#   '316853',
#   0,
#   '#parithabangal #paavangal #ammapaavangal #amma #mothersday #mothersday2024 '
#   '#motherslove #motherspaavangal #shorts \n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['B9bpsJ6G4jY',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'கொளுத்தி போடுறாங்களே எப்படி எரிய போகுதோ😕 | Parithabangal #shorts',
#   '2024-05-17T12:30:12Z',
#   '170',
#   '0',
#   '25869',
#   '458451',
#   0,
#   '#parithabangal #paavangal #ammapaavangal #amma #mothersday #mothersday2024 '
#   '#motherslove #motherspaavangal #shorts \n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['mqC7qI_WtkU',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'Diaper மாத்த ஆள் இல்லனு பாசமா பேசுறானுங்க திருட்டு பசங்க😤 | Parithabangal '
#   '#shorts',
#   '2024-05-16T11:30:24Z',
#   '71',
#   '0',
#   '12428',
#   '164974',
#   60,
#   '#parithabangal #shorts #paavangal #digitalarrestpaavangal #cybercrime '
#   '#cybersecurity #hacking #cyberawareness \n'
#   '\n'
#   'Collab with Tamilnadu Cyber Crime Department.\n'
#   '\n'
#   'for register complaints regarding digital scam and threaten.\n'
#   'click here : https://cybercrime.gov.in/ (or) call toll free number : 1930 \n'
#   '\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['Yj9e9a4WsU8',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'என்னடா புதுசு புதுசா ஏமாத்துறீங்க🙄🤕 | Parithabangal #shorts',
#   '2024-05-15T11:30:14Z',
#   '22',
#   '0',
#   '5031',
#   '88120',
#   60,
#   '#parithabangal #shorts #paavangal #digitalarrestpaavangal #cybercrime '
#   '#cybersecurity #hacking #cyberawareness \n'
#   '\n'
#   'Collab with Tamilnadu Cyber Crime Department.\n'
#   '\n'
#   'for register complaints regarding digital scam and threaten.\n'
#   'click here : https://cybercrime.gov.in/ (or) call toll free number : 1930 \n'
#   '\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['MSr0GsQfxBY',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'Fraud- னு தெரியாம நம்பி ஏமாந்துட்டியே லூசு அப்பா😢 | Parithabangal #shorts',
#   '2024-05-14T13:08:08Z',
#   '47',
#   '0',
#   '28367',
#   '482202',
#   60,
#   '#parithabangal #shorts  #paavangal #digitalarrestpaavangal #cybercrime '
#   '#cybersecurity #hacking #cyberawareness \n'
#   '\n'
#   'Collab with Tamilnadu Cyber Crime Department.\n'
#   '\n'
#   'for register complaints regarding digital scam and threaten.\n'
#   'click here : https://cybercrime.gov.in/ (or) call toll free number : 1930 \n'
#   '\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['8SvwL3a2tAE',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'Digital Arrest Paavangal | Parithabangal',
#   '2024-05-14T11:00:06Z',
#   '1813',
#   '0',
#   '75147',
#   '1502281',
#   1080,
#   '#parithabangal #paavangal #digitalarrestpaavangal #cybercrime '
#   '#cybersecurity #hacking #cyberawareness \n'
#   'Collab with Tamilnadu Cyber Crime Department.\n'
#   '\n'
#   'for register complaints regarding digital scam and threaten.\n'
#   'click here : https://cybercrime.gov.in/ (or) call toll free number : 1930 \n'
#   '\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['sLtCN77Kpcw',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'கறி எடுக்காம இருக்க காரணம் சொல்ல அம்மாவால மட்டும் தான் முடியும்🤕 | '
#   'Parithabangal #Shorts',
#   '2024-05-13T12:00:53Z',
#   '191',
#   '0',
#   '39328',
#   '711158',
#   60,
#   '#parithabangal #paavangal #ammapaavangal #amma #mothersday #mothersday2024 '
#   '#motherslove #motherspaavangal #shorts \n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['xA-jyPkJNEg',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'Mothers Day-ல அதான் இப்படி பாசம் பொங்குது | Parithabangal #shorts',
#   '2024-05-12T11:30:22Z',
#   '104',
#   '0',
#   '27368',
#   '429068',
#   0,
#   '#parithabangal #paavangal #ammapaavangal #amma #mothersday #mothersday2024 '
#   '#motherslove #motherspaavangal #shorts \n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['UxMOY7myAi4',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'Phone பண்ணா எடுக்குறது இல்ல ஆனா Phone மட்டும் பண்ணனுமா🙄 | Parithabangal '
#   '#shorts',
#   '2024-05-11T12:12:43Z',
#   '239',
#   '0',
#   '39246',
#   '524594',
#   0,
#   '#parithabangal #paavangal #ammapaavangal #amma #mothersday #mothersday2024 '
#   '#motherslove #motherspaavangal\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['Xu9HJvE_tLs',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'ஓட்ட தெரியாதவருக்கு Bullet எதுக்கு😂 | Parithabangal #shorts',
#   '2024-05-10T11:30:23Z',
#   '121',
#   '0',
#   '37644',
#   '580309',
#   60,
#   '#parithabangal #paavangal #ammapaavangal #amma #mothersday #mothersday2024 '
#   '#motherslove #motherspaavangal\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['5JadB2Kz2o0',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'Amma Paavangal | Parithabangal',
#   '2024-05-09T11:30:01Z',
#   '3899',
#   '0',
#   '148398',
#   '2586651',
#   840,
#   '#parithabangal #paavangal #ammapaavangal #amma #mothersday #mothersday2024 '
#   '#motherslove #motherspaavangal\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['ckaQvErQaIo',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'Akshaya Triti Parithabangal #shorts',
#   '2024-05-09T09:13:33Z',
#   '170',
#   '0',
#   '29176',
#   '502332',
#   60,
#   '#ad #parithabangal #LalithaJewellery #AkshayaTriti\n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['OBvIllfUFww',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'இதான்டா விஷயம் பயந்து சாகாதிங்க😑 | Parithabangal #shorts',
#   '2024-05-08T11:30:15Z',
#   '55',
#   '0',
#   '11984',
#   '175382',
#   0,
#   '#parithabangal #paavangal #vaccinepaavangal #vaccine #covidshield #shorts \n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['ZhV7ErMjIPc',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'நம்பனும் சும்மா கேள்வியா கேக்கக் கூடாது😒 | Parithabangal #shorts',
#   '2024-05-07T11:30:17Z',
#   '49',
#   '0',
#   '14333',
#   '229114',
#   0,
#   '#parithabangal #paavangal #vaccinepaavangal #vaccine #covidshield #shorts \n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['lALCFaZvJyE',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'அப்போ WWE பொய்னு உனக்கு தெரியாது🙄🤨 | Parithabangal #shorts',
#   '2024-05-06T11:30:30Z',
#   '38',
#   '0',
#   '7069',
#   '93887',
#   0,
#   '#parithabangal #paavangal #vaccinepaavangal #vaccine #covidshield #shorts \n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['bZSoAiWEndY',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'இந்த பன்னாட தான், அத போட சொன்னான்🥲 | Parithabangal #shorts',
#   '2024-05-05T11:30:16Z',
#   '112',
#   '0',
#   '23707',
#   '399692',
#   0,
#   '#parithabangal #paavangal #vaccinepaavangal #vaccine #covidshield #shorts \n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
#   '_____________________________________'],
#  ['B_VDW8jtVf4',
#   'UCueYcgdqos0_PzNOq81zAFg',
#   'Gopi, நா இன்னும் கொஞ்ச நாள்தான் டா இருப்பேன்🥲😂 | Parithabangal #shorts',
#   '2024-05-04T13:00:13Z',
#   '179',
#   '0',
#   '20267',
#   '348103',
#   0,
#   '#parithabangal #paavangal #vaccinepaavangal #vaccine #covidshield #shorts \n'
#   '________________________________\n'
#   '\n'
#   'Starring\n'
#   '\n'
#   'GO-SU\n'
#   'https://www.instagram.com/gopi_aravindh\n'
#   'https://www.instagram.com/duniya_sudhakar\n'
#   'Dravid Selvam: https://www.instagram.com/dravidselvam_6\n'
#   '\n'
#   '________________________________\n'
#   '\n'
#   'Follow our new channel : \n'
#   'Parithabangal Podcast  - '
#   'https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n'
#   '\n'
#   'Follow Us On Social Media\n'
#   '\n'
#   'PARITHABANGAL \n'
#   '\n'
#   'Facebook    -  https://www.facebook.com/ParithabangalProductions/ \n'
#   'Instagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\n'
#   'Twitter     -  https://twitter.com/Parithabangal_\n'
#   'Youtube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n'
#   '___________________________________\n'
#   '\n'
#   'In Association with Divo :\n'
#   'Website   - http://web.divo.in/\n'
#   'Instagram - https://www.instagram.com/divomovies/\n'
#   'Facebook  - http://www.facebook.com/divomovies\n'
#   'Twitter   - https://twitter.com/divomovies\n'
# ...
#   '\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'],
#  ['ru8DCgJnRbA',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'Pozhuthu Vidinchachu 1984 Song Jukebox | Ilaiyaraaja | Prabhu, Sulochana & '
#   'Nambiyar',
#   '2024-04-29T05:50:24Z',
#   '6',
#   '0',
#   '85',
#   '8189',
#   1560,
#   'The Original Soundtrack of Pozhuthu Vidinchachu(1984).\n'
#   'Starring Prabhu,Sulochana & Nambiyar.\n'
#   'Directed by Gangai Amaran.\n'
#   'Music Composed,Arranged & Produced by Maestro Ilaiyaraaja.\n'
#   '\n'
#   'Track List & Time Stamps\n'
#   '************************\n'
#   '00:00 Song Name: Kaatre Sellu..\n'
#   '      Singers: Malaysia Vasudevan & Vani Jayaram.\n'
#   '      Lyricist: Gangai Amaran\n'
#   '\n'
#   '04:20 Song Name: Aatha Manasu..\n'
#   '      Singers: Malaysia Vasudevan & S.P.Shailaja.\n'
#   '      Lyricist:Kavignar Vairamuthu.\n'
#   '\n'
#   '08:56 Song Name: Ettu Thisaiyum..\n'
#   '      Singers: Malaysia Vasudevan & SPB.\n'
#   '      Lyricist:Gangai Amaran.\n'
#   '\n'
#   '13:30 Song Name: Atha Thavamirunthu(F)..\n'
#   '      Singers: S.P.Shailaja\n'
#   '      Lyricist:Kavignar Vaali.\n'
#   '\n'
#   '18:09 Song Name: Atha Thavamirunthu(M)...\n'
#   '      Singers: Malaysia Vasudevan\n'
#   '      Lyricist:Kavignar Vaali.\n'
#   '\n'
#   '22:36 Song Name: Oora Yechu..\n'
#   '      Singers: SPB & Malaysia Vasudevan.\n'
#   '      Lyricist:Gangai Amaran.\n'
#   '\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'],
#  ['5QlTZEogGrE',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'Star Official Trailer | Kavin | Elan | Yuvan Shankar Raja | Lal, Aaditi '
#   'Pohankar, Preity Mukhundhan',
#   '2024-04-27T05:41:00Z',
#   '9186',
#   '0',
#   '283869',
#   '5021980',
#   120,
#   'Writer - Director : Elan\n'
#   'Starring – Kavin, Lal, Aaditi Pohankar, Preity Mukhundhan, Geetha Kailasam\n'
#   'Music Director : Yuvan Shankar Raja\n'
#   'Director of Photography : Ezhil Arasu K\n'
#   'Art Director : Vinoth Raj Kumar N\n'
#   'Editor : Pradeep E Ragav\n'
#   'Stunt Director : Vicky\n'
#   'Costume Designer : Sujith Sudhakaran\n'
#   'Audiography : M R Rajakrishnan\n'
#   'Special Makeup: Libin Mohanan\n'
#   'Makeup : S A Shanmugam\n'
#   'VFX : A Muthukumaran\n'
#   'Stills : Sheik Fareedh\n'
#   'DI: Pixel Light Studio\n'
#   'Colorist: Ranga\n'
#   'Stylist (Aaditi Pohankar) : Abinanthini M\n'
#   'Designs: Venky\n'
#   'Production Executive : G Kannan, Bhalamurugan C, K Kumar\n'
#   'Executive Producer : S Vinoth Kumar\n'
#   'Pro: Yuvraaj\n'
#   'Co Producers: P Rupak Pranav Tej, Sunil Shah, Raja Subramanian\n'
#   'Produced by: B.V.S.N Prasad, Sreenidhi Sagar \n'
#   '\n'
#   'All Score Composed ,Arranged and Produced by\n'
#   'Yuvan Shankar Raja\n'
#   'Keyboards : Rajesh\n'
#   'Solo Violin: Manoj\n'
#   'Flute: Vijay KJ\n'
#   'Strings Orchestrated by Prabhakar\n'
#   'Strings performed by Chennai  Strings \n'
#   'Male Harmonies: Shenbhagaraj,Velu,Aravind Annest\n'
#   'Female Harmonies: Aparna,Hemambika,Abinaya\n'
#   'Harmonies Supervision: Srivardhini \n'
#   'Recording Studios: U1 Records, AM Studios \n'
#   'Sound Engineers: M Kumaraguruparan,Sharan Ravin,Ainul Huq (AM Studios)\n'
#   '\n'
#   'Direction Team : Gerald R, Thava Guru, Sugumar Chandrasekar, Viggnessh '
#   'Saravanan,\n'
#   'Associate Cinematographers: Kannadasan Chezhiyan, M. Adhiran\n'
#   'Assistant Cinematographers: Ajith Kumar P, Rahul S, Dhivahar K\n'
#   'Associate Editor : SS.Stalin\n'
#   'Assistant Editors: Ahmed Asif, Balakumaran, Ganesh Hari \n'
#   'Spot Editor : I.R.K.RAM\n'
#   'Premix Engineers : Balaji.R, S.P Narayanan, Biju Basil, Gautham.M, '
#   'Goutham.G\n'
#   '\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'],
#  ['ISI1cECZfU4',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'Don’U Don’U Don’U Dance Cover by She Unit | Anirudh Ravichander | Dhanush | '
#   'Maari | Tamil Dance Song',
#   '2024-04-25T12:00:05Z',
#   '23',
#   '0',
#   '487',
#   '18959',
#   120,
#   'Choreographed & Performed by She Unit\n'
#   'Team\n'
#   'Suwetha\n'
#   'Ashwitha\n'
#   'Harishmitha\n'
#   'Nishitha\n'
#   'Sanajana\n'
#   'Subhasri\n'
#   '\n'
#   'Song Name - Don’u Don’u Don’u \n'
#   'Singer - Anirudh Ravichander & Alisha Thomas\n'
#   'Music - Anirudh Ravichander\n'
#   'Lyrics - Dhanush\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'],
#  ['jew7RF57mP0',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   '#Valaiyosai In Parallel Universe | #kaathuvaakularendukaadhal  | '
#   'Ilaiyaraaja | #vijaysethupathi',
#   '2024-04-25T09:58:32Z',
#   '3',
#   '0',
#   '666',
#   '15411',
#   0,
#   'Experience the magic of "Valaiyosai" in a parallel universe with '
#   "KaathuVaakula Rendu Kaadhal. Ilaiyaraaja's music and Vijay Sethupathi's "
#   'acting will mesmerize you in this soulful rendition.\n'
#   '\n'
#   'Movie - KaathuVaakula Rendu Kaadhal\n'
#   'Song: Valaiyosai\n'
#   'Singers: S. P. Balasubrahmanyam, Lata Mangeshkar\n'
#   'Lyrics: Vaali\n'
#   'Cast - Vijay Sethupathi, Nayanthara, Samantha\n'
#   'Written and Directed by Vignesh Shivan\n'
#   '\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'],
#  ['uZt9xE45zZI',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'Valaiyosai Song in Parallel Universe | KaathuVaakula Rendu Kaadhal | '
#   'Ilaiyaraaja | Vijay Sethupathi',
#   '2024-04-25T05:38:54Z',
#   '39',
#   '0',
#   '1299',
#   '154840',
#   120,
#   'Experience the magic of "Valaiyosai" in a parallel universe with '
#   "KaathuVaakula Rendu Kaadhal. Ilaiyaraaja's music and Vijay Sethupathi's "
#   'acting will mesmerize you in this soulful rendition.\n'
#   '\n'
#   'Movie - KaathuVaakula Rendu Kaadhal\n'
#   'Song: Valaiyosai\n'
#   'Singers: S. P. Balasubrahmanyam, Lata Mangeshkar\n'
#   'Lyrics: Vaali\n'
#   'Cast - Vijay Sethupathi, Nayanthara, Samantha\n'
#   'Written and Directed by Vignesh Shivan\n'
#   '\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'],
#  ['_HxutpjjvaM',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'Bodyguard | Arikathayaaro (LoFi Flip) | Dileep | Nayanthara |  Ouseppachan '
#   '| Chris Wayne',
#   '2024-04-24T07:14:07Z',
#   '12',
#   '0',
#   '180',
#   '6569',
#   180,
#   'Arikathayaaro (LoFi Flip)\n'
#   'Composed by Ouseppachan\n'
#   'Produced by Chris Wayne\n'
#   'Film - Bodyguard (Malayalam)\n'
#   'Singer - Ranjith Govind\n'
#   'Lyricist - Anil Panachooran\n'
#   '\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'],
#  ['PKB07uN9rO0',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'Behind The Scenes of OCB | Paal Dabba | Tamil Pop Songs 2024',
#   '2024-04-23T12:30:16Z',
#   '7',
#   '0',
#   '98',
#   '6111',
#   180,
#   'Directed by Paal Dabba\n'
#   'Music by Shiv Paul\n'
#   'Edit & Vfx: Viky pup\n'
#   'DI : Nav\n'
#   'DOP - Thejo Bharathwaj\n'
#   'Associate cinematographers - Sundarajan, Harish, Diwakar\n'
#   'BTS - Vimal\n'
#   'BTS Colourist- Dharunprabakaran\n'
#   'Steadicam - Rajaram\n'
#   'FPV - niche films\n'
#   'Sound design R.k. Aswath (DAW Records)\n'
#   'Art Director : Meganathan\n'
#   'Costume designer: Niranjani and Team (Fraylabel)\n'
#   'Choreography: Rohith, Rajaram, Isaac naveen\n'
#   'Makeup : R. Ganapathy & Team\n'
#   'Executive producer : Adithya Krishnamurthy\n'
#   'Production : Sheriff\n'
#   'Photography: rishikesh swaminathan\n'
#   '\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'],
#  ['GY6RFD-uejU',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'Ambigai Neril Vandhaal - Jukebox | Mohan, Raadha, Urvashi | Ilaiyaraaja',
#   '2024-04-23T10:30:16Z',
#   '6',
#   '0',
#   '107',
#   '5545',
#   1500,
#   'The Original Soundtrack of Ambigai Neril Vanthaal(1984).\n'
#   'Starring Mohan,Radha & Urvashi.\n'
#   'Directed by Manivannan.\n'
#   'Music Composed,Arranged & Produced by Maestro Ilaiyaraaja.\n'
#   '\n'
#   'Track List & Time Stamps\n'
#   '************************\n'
#   '00:00 Song Name: Ithu Ilamai..\n'
#   '      Singers: Ramesh & S.Janaki.\n'
#   '      Lyricist: Kavignar Muthulingam\n'
#   '\n'
#   '04:25 Song Name: Maama Malai Neram..\n'
#   '      Singers: S Janaki.\n'
#   '      Lyricist:Gangai Amaran.\n'
#   '\n'
#   '08:25 Song Name: Kalyana Selai..\n'
#   '      Singers: SPB & Shoba Chandrasekhar.\n'
#   '      Lyricist:M.G.Vallaban.\n'
#   '\n'
#   '12:42 Song Name: Kanni Theme..\n'
#   '      Singers: Ramesh & Vani Jayaram\n'
#   '      Lyricist:Kavignar Vairamuthu.\n'
#   '\n'
#   '17:21 Song Name: Annai Thalattu...\n'
#   '      Singers: P.Susheela\n'
#   '      Lyricist:Panchu Arunchalam\n'
#   '\n'
#   '21:45 Song Name: Nathaikkul Muthu(Title Song)...\n'
#   '      Singers: Ilaiyaraaja\n'
#   '      Lyricist:Gangai Amaran.\n'
#   '\n'
#   '\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'],
#  ['K5L2eOW2szY',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'Muthu Engal Sothu Tamil Jukebox | Ilaiyaraaja | Prabhu & Radha',
#   '2024-04-23T07:32:06Z',
#   '4',
#   '0',
#   '85',
#   '4746',
#   1200,
#   'The Original Soundtrack of Muthu Engal Sothu(1983).\n'
#   'Starring Prabhu & Radha.\n'
#   'Directed by G.N.Rangarajan.\n'
#   'Music Composed,Arranged & Produced by Maestro Ilaiyaraaja.\n'
#   '\n'
#   'Track List & Time Stamps\n'
#   '************************\n'
#   '00:00 Song Name: Title Score..\n'
#   '\n'
#   '02:43 Song Name: Yaar Yaaru..\n'
#   '      Singers: Malaysia Vasudevan & S.Janaki.\n'
#   '      Lyricist: Kavignar Vaali\n'
#   '\n'
#   '06:55 Song Name: Nee Enna..\n'
#   '      Singers: Malaysia Vasudevan & S.Janaki.\n'
#   '      Lyricist:Kavignar Vairamuthu.\n'
#   '\n'
#   '11:32 Song Name: Naan Undhan..\n'
#   '      Singers: S.P.Shailaja.\n'
#   '      Lyricist:Kalaivanan Kannadasan.\n'
#   '\n'
#   '16:04 Song Name: Yaar Yaaru..\n'
#   '      Singers: P.Susheela,S.Janaki & B.S.Sasirekha\n'
#   '      Lyricist:Kavignar Vaali.\n'
#   '\n'
#   '\n'
#   '\n'
#   '\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'],
#  ['vaIx1lJqaUo',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'DISCO DISCO 🚀🕺',
#   '2024-04-22T18:03:19Z',
#   '4',
#   '0',
#   '786',
#   '16293',
#   60,
#   ''],
#  ['UIcWTeTDGjQ',
#   'UCn4rEMqKtwBQ6-oEwbd4PcA',
#   'D.I.S.C.O | Trending Version  | Rajinikanth, Poornima | Ilaiyaraaja',
#   '2024-04-22T13:25:10Z',
#   '385',
#   '0',
#   '19119',
#   '581988',
#   120,
#   'Listen to Vaa Vaa Pakkam Vaa Trending Version from the movie Thangamagan\n'
#   '\n'
#   'Movie - Thangamagan\n'
#   'Song - Vaa Vaa Pakkam Vaa\n'
#   'Music - Ilaiyaraaja\n'
#   'Singer - S. P. Balasubrahmanyam, Vani Jayaram \n'
#   'Lyrics - Muthulingham\n'
#   'Cast - Rajinikanth, Poornima\n'
#   'Director - Jagannathan\n'
#   'Banner - Sathya Movies\n'
#   'Producer - Thyagarajan\n'
#   'Music Label - Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   '© 2024 Sony Music Entertainment India Pvt. Ltd.\n'
#   '\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthVevo\n'
#   'Subscribe Now: http://bit.ly/SonyMusicSouthYT\n'
#   'Follow us: https://www.instagram.com/sonymusic_south/\n'
#   'Follow us: Twitter: https://twitter.com/SonyMusicSouth\n'
#   'Like us: Facebook: https://www.facebook.com/SonyMusicSouth\n'
#   'Join our WhatsApp broadcast channel '
#   'https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\n'
#   'Join Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/']]

# %%
Table_name=pd.read_sql_query('''SELECT name FROM sqlite_master WHERE type = 'table' AND name NOT LIKE 'sqlite_%';''',con )

# %%
print("Total Tables are:",len(Table_name))
print("*"*20)
# Out:
# Total Tables are: 3
# ********************

# %%
pd.read_sql_query('select * from videos order by vid_view_count desc limit 20', con)
# Out:
#        video_id                channel_id  \
# 0   QIGYf2erUHo  UCJcCB-QYPIBcbKcBQOTwhiA
# 1   zcaOimCOsmQ  UCJcCB-QYPIBcbKcBQOTwhiA
# 2   EQKYyL6ycSM  UCJcCB-QYPIBcbKcBQOTwhiA
# 3   EUeu-GJyuYw  UCJcCB-QYPIBcbKcBQOTwhiA
# 4   s5RDMG_tUao  UCJcCB-QYPIBcbKcBQOTwhiA
# 5   XGJtiqVzZiA  UCn4rEMqKtwBQ6-oEwbd4PcA
# 6   L9W6yPDOILE  UCueYcgdqos0_PzNOq81zAFg
# 7   tLMoqfR-qCQ  UCJcCB-QYPIBcbKcBQOTwhiA
# 8   YrXAUN3p1IM  UCJcCB-QYPIBcbKcBQOTwhiA
# 9   ZoI2wfj_OX0  UCJcCB-QYPIBcbKcBQOTwhiA
# 10  NPMjsLOPN70  UCJcCB-QYPIBcbKcBQOTwhiA
# 11  4NppfA06-_s  UCJcCB-QYPIBcbKcBQOTwhiA
# 12  FV9xIo7Umlg  UCJcCB-QYPIBcbKcBQOTwhiA
# 13  3q6-_eROVDA  UCJcCB-QYPIBcbKcBQOTwhiA
# 14  EKyT8SVo89s  UCJcCB-QYPIBcbKcBQOTwhiA
# 15  oVHwoZaMD-s  UCJcCB-QYPIBcbKcBQOTwhiA
# 16  6l55q7r4MGU  UCJcCB-QYPIBcbKcBQOTwhiA
# 17  leh7b--yq0c  UCueYcgdqos0_PzNOq81zAFg
# 18  u9tDHRYUJok  UCJcCB-QYPIBcbKcBQOTwhiA
# 19  cu_kqf70vEg  UCJcCB-QYPIBcbKcBQOTwhiA
#
#                                            video_name             public_At  \
# 0   அப்பா hospital - ல இருக்காரு 😥 | insta series ...  2024-01-31T09:30:12Z
# 1   நான் தான் டா Riya Kannan🤣💥 | insta series epi ...  2024-02-05T12:30:10Z
# 2   மாட்டுனடா பம்பரகட்ட மண்டையா 🤣🔥 | Insta series ...  2024-01-28T04:30:13Z
# 3   தல Dhoni- க்கு call பண்ணுங்க😎 | Ft. Rj Balaji ...  2024-01-22T13:30:12Z
# 4   Home Tour - A Bachelor Party Full Movie | 4K w...  2024-01-21T04:30:08Z
# 5   Manamey - Ika Na Maate Lyrical | Sharwanand, K...  2024-03-28T06:04:32Z
# 6                 90ML Boys Paavangal | Parithabangal  2024-03-06T11:30:16Z
# 7   Love Torture பண்றான் டா😔  | insta series epi -...  2024-02-02T09:45:09Z
# 8   Kodaikanal Series Re-release Full Movie 🔥 | 4K...  2024-02-04T04:30:13Z
# 9   Welcome to Ini vlogs | Dubai Series Ep 01 | Vj...  2024-03-20T12:30:08Z
# Query:1 What are the names of all the videos and their corresponding channels?

# %%
Query1 = pd.read_sql_query('SELECT channel_name,video_name FROM videos v JOIN channels c on v.channel_id = c.channel_id ',con)
Query1.head(10)
# Out:
#       channel_name                                         video_name
# 0  Vj Siddhu Vlogs  குரங்குக்கே Love Failure-ஆ😱| Dubai Series EP -...
# 1  Vj Siddhu Vlogs  நாங்க செய்றது தான் சமையல் | Dubai Series EP-9 ...
# 2  Vj Siddhu Vlogs  ஒட்டகம் வாங்கப் போறோம் 😍😋 | Dubai Series EP 8 ...
# 3  Vj Siddhu Vlogs  Super Man-அ பாத்துட்டோம் 😱🔥 |  Dubai Series EP...
# 4  Vj Siddhu Vlogs  Rugged Boy-ஆ நீங்க 😱🤙🏻| GV Prakash| Vj Siddhu ...
# 5  Vj Siddhu Vlogs  இவனுங்கள நம்புனா இப்டி தான் 😫 Dubai Series EP ...
# 6  Vj Siddhu Vlogs  எப்போபா Theme Park போறோம் 😕🥺  | Dubai Series E...
# 7  Vj Siddhu Vlogs  Theme Park போறோம் 😍  | Dubai Series EP 4 | Vj ...
# 8  Vj Siddhu Vlogs  Sorry இனியாழ்🥹 | Dubai Series EP 3 | Vj Siddhu...
# 9  Vj Siddhu Vlogs  Direction விட Acting ஜாலியா இருக்கு 😜 | Vj Sid...

# %% [markdown]
# Query:2
# Which channels have the most number of videos, and how many videos do
#  they have?

# %%
Query2 = pd.read_sql_query('SELECT channel_name, max(video_count) from channels' ,con)
Query2

# %% [markdown]
# Query:3 What are the top 10 most viewed videos and their respective channels?

# %%
Query3 = pd.read_sql_query('SELECT channel_name, video_name,vid_view_count FROM videos v JOIN channels c on v.channel_id = c.channel_id order by vid_view_count desc limit 10 ',con)
Query3

# %% [markdown]
# Query:4 How many comments were made on each video, and what are their corresponding video names?

# %%
Query4 = pd.read_sql_query('SELECT video_name, comment_count FROM videos',con)
Query4

# %% [markdown]
# Query:5 Which videos have the highest number of likes, and what are their corresponding channel names?

# %%
Query5 = pd.read_sql_query('SELECT channel_name, video_name, like_count FROM videos v JOIN channels c on v.channel_id = c.channel_id  ORDER BY like_count DESC LIMIT 10',con)
Query5
# Out:
#       channel_name                                         video_name  \
# 0  Vj Siddhu Vlogs  வானத்துல Cake வெட்றோம் 🥳🤩 | Sri Lanka EP01 | V...
# 1  Vj Siddhu Vlogs  மாட்டுனடா பம்பரகட்ட மண்டையா 🤣🔥 | Insta series ...
# 2  Vj Siddhu Vlogs  அப்பா hospital - ல இருக்காரு 😥 | insta series ...
# 3  Vj Siddhu Vlogs  நான் தான் டா Riya Kannan🤣💥 | insta series epi ...
# 4  Vj Siddhu Vlogs  தல Dhoni- க்கு call பண்ணுங்க😎 | Ft. Rj Balaji ...
# 5  Vj Siddhu Vlogs  Welcome to Ini vlogs | Dubai Series Ep 01 | Vj...
# 6  Vj Siddhu Vlogs  உன்ன பாத்தா எனக்கு கேன பையனு தோணுது😂😱 | Ft.Vij...
# 7  Vj Siddhu Vlogs  Love Torture பண்றான் டா😔  | insta series epi -...
# 8  Vj Siddhu Vlogs  எல்லாருமே ஒற்றுமையா இருக்கீங்க🥰❤️ | Sri Lanka ...
# 9  Vj Siddhu Vlogs  தலைவர் படத்துல நடிக்க போறோம் 😍🔥 | Lokesh Kanag...
#
#    like_count
# 0      249428
# 1      244108
# 2      236940
# 3      232699
# 4      214945
# 5      201749
# 6      201526
# 7      198952
# 8      194447
# 9      192891

# %% [markdown]
# Query:6 What is the total number of likes and dislikes for each video, and what are their corresponding video names?

# %%
Query6 = pd.read_sql_query('SELECT video_name,like_count FROM videos',con)
Query6
# Out:
#                                             video_name  like_count
# 0    குரங்குக்கே Love Failure-ஆ😱| Dubai Series EP -...      152740
# 1    நாங்க செய்றது தான் சமையல் | Dubai Series EP-9 ...      161323
# 2    ஒட்டகம் வாங்கப் போறோம் 😍😋 | Dubai Series EP 8 ...      142419
# 3    Super Man-அ பாத்துட்டோம் 😱🔥 |  Dubai Series EP...      151919
# 4    Rugged Boy-ஆ நீங்க 😱🤙🏻| GV Prakash| Vj Siddhu ...      146755
# ..                                                 ...         ...
# 142  All Time Love Hits Malayalam Vol.2 Malayalam S...         111
# 143  Mayilppeelikkavu Malayalam Songs Jukebox | Ber...          10
# 144           Bharatanatya Gaanangal Malayalam Jukebox           2
# 145  Mayapponman Malayalam Songs Jukebox | Mohan Si...           4
# 146  Mazhavillu Malayalam Songs Jukebox | Mohan Sit...           5
#
# [147 rows x 2 columns]

# %% [markdown]
# Query:7 What is the total number of views for each channel, and what are their corresponding channel names?

# %%
Query7 = pd.read_sql_query('SELECT channel_name,video_name,like_count FROM videos JOIN channels ORDER BY like_count DESC LIMIT 10',con)
Query7
# Out:
#        channel_name                                         video_name  \
# 0   Vj Siddhu Vlogs  வானத்துல Cake வெட்றோம் 🥳🤩 | Sri Lanka EP01 | V...
# 1     Parithabangal  வானத்துல Cake வெட்றோம் 🥳🤩 | Sri Lanka EP01 | V...
# 2  Sony Music South  வானத்துல Cake வெட்றோம் 🥳🤩 | Sri Lanka EP01 | V...
# 3   Vj Siddhu Vlogs  மாட்டுனடா பம்பரகட்ட மண்டையா 🤣🔥 | Insta series ...
# 4     Parithabangal  மாட்டுனடா பம்பரகட்ட மண்டையா 🤣🔥 | Insta series ...
# 5  Sony Music South  மாட்டுனடா பம்பரகட்ட மண்டையா 🤣🔥 | Insta series ...
# 6   Vj Siddhu Vlogs  அப்பா hospital - ல இருக்காரு 😥 | insta series ...
# 7     Parithabangal  அப்பா hospital - ல இருக்காரு 😥 | insta series ...
# 8  Sony Music South  அப்பா hospital - ல இருக்காரு 😥 | insta series ...
# 9   Vj Siddhu Vlogs  நான் தான் டா Riya Kannan🤣💥 | insta series epi ...
#
#    like_count
# 0      249428
# 1      249428
# 2      249428
# 3      244108
# 4      244108
# 5      244108
# 6      236940
# 7      236940
# 8      236940
# 9      232699

# %% [markdown]
#  Query:8 What are the names of all the channels that have published videos in the year 2022?

# %%
Query8 = pd.read_sql_query("SELECT channel_name,public_At FROM videos v JOIN channels c on v.channel_id = c.channel_id",con)
Query8['public_At'] = pd.to_datetime(Query8['public_At'])
#--------------------

mask = Query8['public_At'].dt.year == int(2024)
Query8 = Query8[mask]
Query8
# Out:
#          channel_name                 public_At
# 0     Vj Siddhu Vlogs 2024-04-10 11:15:07+00:00
# 1     Vj Siddhu Vlogs 2024-04-08 09:30:08+00:00
# 2     Vj Siddhu Vlogs 2024-04-07 04:30:08+00:00
# 3     Vj Siddhu Vlogs 2024-04-05 09:30:08+00:00
# 4     Vj Siddhu Vlogs 2024-04-03 09:30:08+00:00
# ..                ...                       ...
# 142  Sony Music South 2024-03-26 18:30:42+00:00
# 143  Sony Music South 2024-03-26 18:30:42+00:00
# 144  Sony Music South 2024-03-26 18:30:41+00:00
# 145  Sony Music South 2024-03-26 18:30:38+00:00
# 146  Sony Music South 2024-03-26 18:30:27+00:00
#
# [147 rows x 2 columns]

# %% [markdown]
# Query:9 What is the average duration of all videos in each channel, and what are their corresponding channel names?

# %%
Query9 = pd.read_sql_query('SELECT channel_name, avg(vid_duration) FROM videos v JOIN channels c on v.channel_id = c.channel_id group by channel_name',con)
Query9
# Out:
#        channel_name  avg(vid_duration)
# 0     Parithabangal         277.959184
# 1  Sony Music South        1070.204082
# 2   Vj Siddhu Vlogs        1455.918367

# %% [markdown]
#  Query:10 Which videos have the highest number of comments, and what are their corresponding channel names?

# %%
Query10= pd.read_sql_query('SELECT channel_name,comment_count FROM videos v JOIN channels c on v.channel_id = c.channel_id order by comment_count desc limit 20',con)
Query10
# Out:
#        channel_name  comment_count
# 0   Vj Siddhu Vlogs          10448
# 1   Vj Siddhu Vlogs           6542
# 2   Vj Siddhu Vlogs           5784
# 3   Vj Siddhu Vlogs           5372
# 4   Vj Siddhu Vlogs           4728
# 5   Vj Siddhu Vlogs           4068
# 6   Vj Siddhu Vlogs           3642
# 7   Vj Siddhu Vlogs           3440
# 8   Vj Siddhu Vlogs           3225
# 9   Vj Siddhu Vlogs           3158
# 10  Vj Siddhu Vlogs           3132
# 11  Vj Siddhu Vlogs           2962
# 12    Parithabangal           2917
# 13  Vj Siddhu Vlogs           2897
# 14  Vj Siddhu Vlogs           2879
# 15  Vj Siddhu Vlogs           2853
# 16    Parithabangal           2778
# 17  Vj Siddhu Vlogs           2741
# 18  Vj Siddhu Vlogs           2632
# 19  Vj Siddhu Vlogs           2599

# %%
print(list(con.execute('select * from channels')))
# Out:
# [('Vj Siddhu Vlogs', 'UCJcCB-QYPIBcbKcBQOTwhiA', '2023-06-14T07:41:42.139364Z', 'UUJcCB-QYPIBcbKcBQOTwhiA', 2480000, 183, 384891438), ('Parithabangal', 'UCueYcgdqos0_PzNOq81zAFg', '2018-02-08T17:44:41Z', 'UUueYcgdqos0_PzNOq81zAFg', 5440000, 822, 1348775665), ('Sony Music South', 'UCn4rEMqKtwBQ6-oEwbd4PcA', '2014-08-06T15:11:11Z', 'UUn4rEMqKtwBQ6-oEwbd4PcA', 17100000, 3457, 12328051498)]
